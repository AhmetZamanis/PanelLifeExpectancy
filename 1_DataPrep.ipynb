# %%
import pandas as pd
import numpy as np

# %%
# Set print options
np.set_printoptions(suppress=True, precision=6, edgeitems = 7)
pd.options.display.float_format = '{:.6f}'.format
pd.set_option('display.max_columns', None)

# %%
# Read data
df = pd.read_csv("./InputData/raw_data.csv")

# %%
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing         65.000000       263.000000
# 1     Afghanistan  2014  Developing         59.900000       271.000000
# 2     Afghanistan  2013  Developing         59.900000       268.000000
# 3     Afghanistan  2012  Developing         59.500000       272.000000
# 4     Afghanistan  2011  Developing         59.200000       275.000000
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing         44.300000       723.000000
# 2934     Zimbabwe  2003  Developing         44.500000       715.000000
# 2935     Zimbabwe  2002  Developing         44.800000        73.000000
# 2936     Zimbabwe  2001  Developing         45.300000       686.000000
# 2937     Zimbabwe  2000  Developing         46.000000       665.000000
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62 0.010000               71.279624    65.000000      1154
# 1                64 0.010000               73.523582    62.000000       492
# 2                66 0.010000               73.219243    64.000000       430
# 3                69 0.010000               78.184215    67.000000      2787
# 4                71 0.010000                7.097109    68.000000      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27 4.360000                0.000000    68.000000        31
# 2934             26 4.060000                0.000000     7.000000       998
# 2935             25 4.430000                0.000000    73.000000       304
# 2936             25 1.720000                0.000000    76.000000       529
# 2937             24 1.680000                0.000000    79.000000      1483
#
#           BMI   under-five deaths      Polio  Total expenditure  Diphtheria   \
# 0    19.100000                  83  6.000000           8.160000    65.000000
# 1    18.600000                  86 58.000000           8.180000    62.000000
# 2    18.100000                  89 62.000000           8.130000    64.000000
# 3    17.600000                  93 67.000000           8.520000    67.000000
# 4    17.200000                  97 68.000000           7.870000    68.000000
# ...        ...                 ...       ...                ...          ...
# 2933 27.100000                  42 67.000000           7.130000    65.000000
# 2934 26.700000                  41  7.000000           6.520000    68.000000
# 2935 26.300000                  40 73.000000           6.530000    71.000000
# 2936 25.900000                  39 76.000000           6.160000    75.000000
# 2937 25.500000                  39 78.000000           7.100000    78.000000
#
#        HIV/AIDS        GDP      Population   thinness  1-19 years  \
# 0      0.100000 584.259210 33736494.000000              17.200000
# 1      0.100000 612.696514   327582.000000              17.500000
# 2      0.100000 631.744976 31731688.000000              17.700000
# 3      0.100000 669.959000  3696958.000000              17.900000
# 4      0.100000  63.537231  2978599.000000              18.200000
# ...         ...        ...             ...                    ...
# 2933  33.600000 454.366654 12777511.000000               9.400000
# 2934  36.700000 453.351155 12633897.000000               9.800000
# 2935  39.800000  57.348340   125525.000000               1.200000
# 2936  42.100000 548.587312 12366165.000000               1.600000
# 2937  43.500000 547.358878 12222251.000000              11.000000
#
#        thinness 5-9 years  Income composition of resources  Schooling
# 0               17.300000                         0.479000  10.100000
# 1               17.500000                         0.476000  10.000000
# 2               17.700000                         0.470000   9.900000
# 3               18.000000                         0.463000   9.800000
# 4               18.200000                         0.454000   9.500000
# ...                   ...                              ...        ...
# 2933             9.400000                         0.407000   9.200000
# 2934             9.900000                         0.418000   9.500000
# 2935             1.300000                         0.427000  10.000000
# 2936             1.700000                         0.427000   9.800000
# 2937            11.200000                         0.434000   9.800000
#
# [2938 rows x 22 columns]

# %%
# Standardize column names
df.columns = df.columns.str.lower().str.strip().str.replace(" ", "_")

# %%
# Rename columns
df = df.rename({"under-five_deaths": "under_five_deaths",
          'hiv/aids': 'hiv_aids',
          'thinness__1-19_years': 'thinness_1_19',
          'thinness_5-9_years': 'thinness_5_9'}, axis = 1)

# %%
# Drop possible "confounded" variables
df = df.drop(["adult_mortality", "infant_deaths", "under_five_deaths"], axis = 1)

# %%
# Check missing values
pd.isnull(df).sum()
# Out:
# country                              0
# year                                 0
# status                               0
# life_expectancy                     10
# alcohol                            194
# percentage_expenditure               0
# hepatitis_b                        553
# measles                              0
# bmi                                 34
# polio                               19
# total_expenditure                  226
# diphtheria                          19
# hiv_aids                             0
# gdp                                448
# population                         652
# thinness_1_19                       34
# thinness_5_9                        34
# income_composition_of_resources    167
# schooling                          163
# dtype: int64

# %%
# Drop missing values
df = df.dropna()

# %%
# Check for unusual values
df.describe()
# Out:
#              year  life_expectancy     alcohol  percentage_expenditure  \
# count 1649.000000      1649.000000 1649.000000             1649.000000
# mean  2007.840509        69.302304    4.533196              698.973558
# std      4.087711         8.796834    4.029189             1759.229336
# min   2000.000000        44.000000    0.010000                0.000000
# 25%   2005.000000        64.400000    0.810000               37.438577
# 50%   2008.000000        71.700000    3.790000              145.102253
# 75%   2011.000000        75.000000    7.340000              509.389994
# max   2015.000000        89.000000   17.870000            18961.348600
#
#        hepatitis_b       measles         bmi       polio  total_expenditure  \
# count  1649.000000   1649.000000 1649.000000 1649.000000        1649.000000
# mean     79.217708   2224.494239   38.128623   83.564585           5.955925
# std      25.604664  10085.802019   19.754249   22.450557           2.299385
# min       2.000000      0.000000    2.000000    3.000000           0.740000
# 25%      74.000000      0.000000   19.500000   81.000000           4.410000
# 50%      89.000000     15.000000   43.700000   93.000000           5.840000
# 75%      96.000000    373.000000   55.800000   97.000000           7.470000
# max      99.000000 131441.000000   77.100000   99.000000          14.390000
#
#        diphtheria    hiv_aids           gdp        population  thinness_1_19  \
# count 1649.000000 1649.000000   1649.000000       1649.000000    1649.000000
# mean    84.155246    1.983869   5566.031887   14653625.889485       4.850637
# std     21.579193    6.032360  11475.900117   70460393.403056       4.599228
# min      2.000000    0.100000      1.681350         34.000000       0.100000
# 25%     82.000000    0.100000    462.149650     191897.000000       1.600000
# 50%     92.000000    0.100000   1592.572182    1419631.000000       3.000000
# 75%     97.000000    0.700000   4718.512910    7658972.000000       7.100000
# max     99.000000   50.600000 119172.741800 1293859294.000000      27.200000
#
#        thinness_5_9  income_composition_of_resources   schooling
# count   1649.000000                      1649.000000 1649.000000
# mean       4.907762                         0.631551   12.119891
# std        4.653757                         0.183089    2.795388
# min        0.100000                         0.000000    4.200000
# 25%        1.700000                         0.509000   10.300000
# 50%        3.200000                         0.673000   12.300000
# 75%        7.100000                         0.751000   14.000000
# max       28.200000                         0.936000   20.700000

# %%
# Dummy encode "status" as developing 0/1
df["developing"] = (df["status"] == "Developing").astype(int)
df = df.drop("status", axis = 1)

# %%
df.head()
# Out:
#        country  year  life_expectancy  alcohol  percentage_expenditure  \
# 0  Afghanistan  2015        65.000000 0.010000               71.279624
# 1  Afghanistan  2014        59.900000 0.010000               73.523582
# 2  Afghanistan  2013        59.900000 0.010000               73.219243
# 3  Afghanistan  2012        59.500000 0.010000               78.184215
# 4  Afghanistan  2011        59.200000 0.010000                7.097109
#
#    hepatitis_b  measles       bmi     polio  total_expenditure  diphtheria  \
# 0    65.000000     1154 19.100000  6.000000           8.160000   65.000000
# 1    62.000000      492 18.600000 58.000000           8.180000   62.000000
# 2    64.000000      430 18.100000 62.000000           8.130000   64.000000
# 3    67.000000     2787 17.600000 67.000000           8.520000   67.000000
# 4    68.000000     3013 17.200000 68.000000           7.870000   68.000000
#
#    hiv_aids        gdp      population  thinness_1_19  thinness_5_9  \
# 0  0.100000 584.259210 33736494.000000      17.200000     17.300000
# 1  0.100000 612.696514   327582.000000      17.500000     17.500000
# 2  0.100000 631.744976 31731688.000000      17.700000     17.700000
# 3  0.100000 669.959000  3696958.000000      17.900000     18.000000
# 4  0.100000  63.537231  2978599.000000      18.200000     18.200000
#
#    income_composition_of_resources  schooling  developing
# 0                         0.479000  10.100000           1
# 1                         0.476000  10.000000           1
# 2                         0.470000   9.900000           1
# 3                         0.463000   9.800000           1
# 4                         0.454000   9.500000           1

# %% [markdown]
# - Grouping variables: country, year

# %%
# Save modified data
df.to_csv("./OutputData/training_data.csv", index = False)
